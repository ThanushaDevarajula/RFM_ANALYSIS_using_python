# %% [markdown]
# # RFM ANALYSIS

# %%
import numpy as np, pandas as pd

# %%
data = pd.read_excel('Online Retail.xlsx')

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # Missing value analysis

# %%
data.isnull().sum(axis=0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ##### * There are missing value in two columns (description, customer ID)

# %%
data.CustomerID.nunique() # we need to delete there row customerID row wise in order to segment the remaining customer
# Out:
# 4372

# %%
d1 = data[pd.notnull(data['CustomerID'])]

# %%
d1.isnull().sum(axis=0)
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# #### Univarient analysis

# %%
d1.drop(['InvoiceNo','StockCode'], axis=1).head()#drop (InvoiceNo,StocjCode) columns
# Out:
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
d1.Country.nunique()
# Out:
# 37

# %%
def unique_counts(df1):
   for i in df1.columns:
       count = df1[i].nunique()
       print(i, ": ", count)
unique_counts(d1)
# Out:
# InvoiceNo :  22190
# StockCode :  3684
# Description :  3896
# Quantity :  436
# InvoiceDate :  20460
# UnitPrice :  620
# CustomerID :  4372
# Country :  37

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
customer_country=data[['Country','CustomerID']].drop_duplicates()  #analyzing Duplicate Values and removing them

# %% [markdown]
# ### *count of customers from each country

# %%
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 36        United Kingdom        3950
# 14               Germany          95
# 13                France          87
# 31                 Spain          31
# 3                Belgium          25
# 33           Switzerland          21
# 27              Portugal          19
# 19                 Italy          15
# 12               Finland          12
# 1                Austria          11
# 25                Norway          10
# 24           Netherlands           9
# 0              Australia           9
# 6        Channel Islands           9
# 9                Denmark           9
# 7                 Cyprus           8
# 32                Sweden           8
# 20                 Japan           8
# 26                Poland           6
# 34                   USA           4
# 5                 Canada           4
# 37           Unspecified           4
# 18                Israel           4
# 15                Greece           4
# ...

# %% [markdown]
# ##### More customers in the data are from the United Kingdom.

# %% [markdown]
# ### RFM analysis for customers from United Kingdom

# %%
d1 = d1.loc[data['Country'] == 'United Kingdom']

# %%
d1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  486286.000000  486286.000000  354345.000000
# mean        9.734640       3.794976   15552.436219
# std       163.262428      41.271159    1594.546025
# min         1.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   14194.000000
# 50%         3.000000       2.100000   15522.000000
# 75%        10.000000       4.130000   16931.000000
# max     80995.000000   13541.330000   18287.000000

# %%
d1.Quantity.min()  ## there are some negative values in the qunatity column
# Out:
# -80995

# %%
sum(d1.UnitPrice<0)  ## 2 negative values are present in the UnitPrice column
# Out:
# 0

# %%
d1.shape
# Out:
# (406829, 8)

# %%
d1 = d1[(d1['Quantity']>0)] #remove all the negative values from the data with respective to the column 'Quantity'

# %%
d1.shape
# Out:
# (397924, 8)

# %%
d1 = d1[(d1['UnitPrice']>0)]

# %%
d1.shape
# Out:
# (397884, 8)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397884 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      397884 non-null object
# StockCode      397884 non-null object
# Description    397884 non-null object
# Quantity       397884 non-null int64
# InvoiceDate    397884 non-null datetime64[ns]
# UnitPrice      397884 non-null float64
# CustomerID     397884 non-null float64
# Country        397884 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.3+ MB

# %%
#to get unique count for every column in the dataset

# %%
def unique_counts(df1):
   for i in df1.columns:
       count = df1[i].nunique()
       print(i, ": ", count)
unique_counts(d1)
# Out:
# InvoiceNo :  16649
# StockCode :  3645
# Description :  3844
# Quantity :  294
# InvoiceDate :  15615
# UnitPrice :  403
# CustomerID :  3921
# Country :  1

# %% [markdown]
# ##### Add a column to the dataset to get monitary values

# %%
d1['TotalPrice'] = d1['Quantity'] * d1['UnitPrice']

# %%
#TO find frequency

# %%
d1['InvoiceDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
d1['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
d1.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# TotalPrice            float64
# dtype: object

# %%
import datetime as dt   ##convert class of invoiceData to datetime 
NOW = dt.datetime(2011,12,10)
d1['InvoiceDate'] = pd.to_datetime(d1['InvoiceDate'])

# %% [markdown]
# #### RFM TABLE

# %%
rfmTable = d1.groupby('CustomerID').agg({'InvoiceDate': lambda x: (NOW - x.max()).days, 'InvoiceNo': lambda x: len(x), 'TotalPrice': lambda x: x.sum()})
rfmTable['InvoiceDate'] = rfmTable['InvoiceDate'].astype(int)
rfmTable.rename(columns={'InvoiceDate': 'recency', 
                         'InvoiceNo': 'frequency', 
                         'TotalPrice': 'monetary_value'}, inplace=True)

# %%
rfmTable.head()
# Out:
#             recency  frequency  monetary_value
# CustomerID
# 12346.0         325          1        77183.60
# 12347.0           2        182         4310.00
# 12348.0          75         31         1797.24
# 12349.0          18         73         1757.55
# 12350.0         310         17          334.40

# %%
#The lowest recency, highest frequency and monetary amounts are our best customers.

# %%
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
segmented_rfm = rfmTable

# %%
quantiles = rfmTable.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()

# %%
segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))

# %%
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str)+ segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)

# %%
#Add a new column RFMscore

# %%
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           4           4
# 12347.0           2        182         4310.00           1           1
# 12348.0          75         31         1797.24           3           3
# 12349.0          18         73         1757.55           2           2
# 12350.0         310         17          334.40           4           4
#
#             m_quartile RFMScore
# CustomerID
# 12346.0              1      441
# 12347.0              1      111
# 12348.0              1      331
# 12349.0              1      221
# 12350.0              3      443

# %%
#sort by monetary_value

# %%
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('monetary_value', ascending=False)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 14646.0           1       2076       280206.02           1           1
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 14911.0           1       5675       143825.06           1           1
# 14156.0           9       1400       117379.63           1           1
# 17511.0           2        963        91062.38           1           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
# 13089.0           2       1818        58825.83           1           1
# 15769.0           7        130        56252.72           1           1
# ...

# %% [markdown]
# #### And here we got the top 10 customers

# %%
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 14646.0           1       2076       280206.02           1           1
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 14911.0           1       5675       143825.06           1           1
# 14156.0           9       1400       117379.63           1           1
# 17511.0           2        963        91062.38           1           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
#
#             m_quartile RFMScore
# CustomerID
# 14646.0              1      111
# 18102.0              1      111
# 17450.0              1      111
# ...
